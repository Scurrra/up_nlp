# %% [markdown]
# # Datasets preparation

# %%
import pandas as pd

# %% [markdown]
# ## [BBC News Archive](https://www.kaggle.com/datasets/hgultekin/bbcnewsarchive)

# %%
bbcnd_data = pd.read_csv("data/bbc-news-data.csv", delimiter="\t")
bbcnd_data.head()
# Out:
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content
# 0   Quarterly profits at US media giant TimeWarne...
# 1   The dollar has hit its highest level against ...
# 2   The owners of embattled Russian oil giant Yuk...
# 3   British Airways has blamed high fuel prices f...
# 4   Shares in UK drinks and food firm Allied Dome...

# %%
bbcnd_data.drop(columns=["filename"], inplace=True)
bbcnd_data.insert(0, "source", "BBC News")

# %%
bbcnd_data.describe()
# Out:
#           source category                             title  \
# count       2225     2225                              2225
# unique         1        5                              2096
# top     BBC News    sport  Microsoft seeking spyware trojan
# freq        2225      511                                 2
#
#                                                   content
# count                                                2225
# unique                                               2092
# top      Microsoft has warned PC users to update their...
# freq                                                    2

# %%
bbcnd_data.groupby("category").count()
# Out:
#                source  title  content
# category
# business          510    510      510
# entertainment     386    386      386
# politics          417    417      417
# sport             511    511      511
# tech              401    401      401

# %% [markdown]
# ## [News Articles](https://www.kaggle.com/datasets/asad1m9a9h6mood/news-articles)

# %%
na_data = pd.read_csv("data/news-articles.csv", encoding='latin', index_col=0)
na_data.head()
# Out:
#                                              Article      Date  \
# 0  KARACHI: The Sindh government has decided to b...  1/1/2015
# 1  HONG KONG: Asian markets started 2015 on an up...  1/2/2015
# 2  HONG KONG:  Hong Kong shares opened 0.66 perce...  1/5/2015
# 3  HONG KONG: Asian markets tumbled Tuesday follo...  1/6/2015
# 4  NEW YORK: US oil prices Monday slipped below $...  1/6/2015
#
#                                              Heading  NewsType
# 0  sindh govt decides to cut public transport far...  business
# 1                    asia stocks up in new year trad  business
# 2           hong kong stocks open 0.66 percent lower  business
# 3             asian stocks sink euro near nine year   business
# 4                 us oil prices slip below 50 a barr  business

# %%
na_data.rename(columns={
    "Heading": "title",
    "NewsType": "category",
    "Date": "date"
}, inplace=True)
na_data.loc[na_data.category=="sports", "category"] = "sport"
na_data.insert(0, "source", "The News")

na_data.head()
# Out:
#      source                                            Article      date  \
# 0  The News  KARACHI: The Sindh government has decided to b...  1/1/2015
# 1  The News  HONG KONG: Asian markets started 2015 on an up...  1/2/2015
# 2  The News  HONG KONG:  Hong Kong shares opened 0.66 perce...  1/5/2015
# 3  The News  HONG KONG: Asian markets tumbled Tuesday follo...  1/6/2015
# 4  The News  NEW YORK: US oil prices Monday slipped below $...  1/6/2015
#
#                                                title  category
# 0  sindh govt decides to cut public transport far...  business
# 1                    asia stocks up in new year trad  business
# 2           hong kong stocks open 0.66 percent lower  business
# 3             asian stocks sink euro near nine year   business
# 4                 us oil prices slip below 50 a barr  business

# %%
def place_from_the_new(s):
    colon = s.find(":")
    return [
        s[:colon],
        s[colon+2:].strip()
    ]

# %%
na_data["content"] = na_data.Article.apply(lambda s: place_from_the_new(s)[1])
na_data.drop(columns=["Article"], inplace=True)
na_data.head()
# Out:
#      source      date                                              title  \
# 0  The News  1/1/2015  sindh govt decides to cut public transport far...
# 1  The News  1/2/2015                    asia stocks up in new year trad
# 2  The News  1/5/2015           hong kong stocks open 0.66 percent lower
# 3  The News  1/6/2015             asian stocks sink euro near nine year
# 4  The News  1/6/2015                 us oil prices slip below 50 a barr
#
#    category                                            content
# 0  business  The Sindh government has decided to bring down...
# 1  business  Asian markets started 2015 on an upswing in li...
# 2  business  Hong Kong shares opened 0.66 percent lower Mon...
# 3  business  Asian markets tumbled Tuesday following painfu...
# 4  business  US oil prices Monday slipped below $50 a barre...

# %%
na_data.date = pd.to_datetime(na_data.date).dt.date

# %%
na_data.describe()
# Out:
#           source        date                                         title  \
# count       2692        2692                                          2692
# unique         1         666                                          2581
# top     The News  2016-08-01  IMF release final instalment 66 bn loan Paki
# freq        2692          27                                             5
#
#        category                                            content
# count      2692                                               2692
# unique        2                                               2584
# top       sport  Tokyo stocks climbed in early trading Friday a...
# freq       1408                                                  5

# %%
na_data.groupby("category").count()
# Out:
#           source  date  title  content
# category
# business    1284  1284   1284     1284
# sport       1408  1408   1408     1408

# %% [markdown]
# ## [CNN News Articles from 2011 to 2022](https://www.kaggle.com/datasets/hadasu92/cnn-articles-after-basic-cleaning)

# %%
cnn_data = pd.read_csv("data/cnn-articels-clean-2.csv", index_col="Index")
cnn_data.head()
# Out:
#                                                   Author       Date published  \
# Index
# 0                                     Jacopo Prisco, CNN  2021-07-15 02:46:59
# 1                                  Stephanie Bailey, CNN  2021-05-12 07:52:09
# 2      Words by Stephanie Bailey, video by Zahra Jamshed  2021-06-16 02:51:30
# 3                                         Kathryn Vasel   2022-03-18 14:37:21
# 4                        Paul R. La Monica, CNN Business  2022-03-19 11:41:08
#
#        Category    Section                                                Url  \
# Index
# 0          news      world  https://www.cnn.com/2021/07/14/world/tusimple-...
# 1          news      world  https://www.cnn.com/2021/05/12/world/ironhand-...
# 2          news       asia  https://www.cnn.com/2021/06/15/asia/swarm-robo...
# 3      business    success  https://www.cnn.com/2022/03/18/success/pandemi...
# 4      business  investing  https://www.cnn.com/2022/03/19/investing/march...
#
#                                                 Headline  \
# Index
# 0      There's a shortage of truckers, but TuSimple t...
# 1      Bioservo's robotic 'Ironhand' could protect fa...
# 2      This swarm of robots gets smarter the more it ...
# 3      Two years later, remote work has changed milli...
# 4              Why March is so volatile for stocks - CNN
#
#                                              Description  \
# Index
# 0      The e-commerce boom has exacerbated a global t...
# 1      Working in a factory can mean doing the same t...
# 2      In a Hong Kong warehouse, a swarm of autonomou...
# 3      Here's a look at how the pandemic reshaped peo...
# 4      March Madness isn't just for college basketbal...
#
#                                                 Keywords  \
# Index
# 0      world, There's a shortage of truckers, but TuS...
# 1      world, Bioservo's robotic 'Ironhand' could pro...
# 2      asia, This swarm of robots gets smarter the mo...
# 3      success, Two years later, remote work has chan...
# 4      investing, Why March is so volatile for stocks...
#
#                                          Second headline  \
# Index
# 0      There's a shortage of truckers, but TuSimple t...
# 1      A robotic 'Ironhand' could protect factory wor...
# 2      This swarm of robots gets smarter the more it ...
# 3      Two years later, remote work has changed milli...
# 4                    Why March is so volatile for stocks
#
#                                             Article text
# Index
# 0       (CNN)Right now, there's a shortage of truck d...
# 1       (CNN)Working in a factory or warehouse can me...
# 2       (CNN)In a Hong Kong warehouse, a swarm of aut...
# 3      The pandemic thrust the working world into a n...
# 4      New York (CNN Business)March Madness isn't jus...

# %%
cnn_data.drop(columns=[
    "Author", "Url",
    "Keywords", "Second headline"
], inplace=True)

cnn_data.rename(columns={
    "Date published": "date",
    "Category": "category",
    "Section": "section",
    "Description": "description",
    "Article text": "content",
    "Headline": "title"
}, inplace=True)

cnn_data.date = pd.to_datetime(cnn_data.date).dt.date

cnn_data.insert(0, "source", "CNN")

# %%
cnn_data.head()
# Out:
#       source        date  category    section  \
# Index
# 0        CNN  2021-07-15      news      world
# 1        CNN  2021-05-12      news      world
# 2        CNN  2021-06-16      news       asia
# 3        CNN  2022-03-18  business    success
# 4        CNN  2022-03-19  business  investing
#
#                                                    title  \
# Index
# 0      There's a shortage of truckers, but TuSimple t...
# 1      Bioservo's robotic 'Ironhand' could protect fa...
# 2      This swarm of robots gets smarter the more it ...
# 3      Two years later, remote work has changed milli...
# 4              Why March is so volatile for stocks - CNN
#
#                                              description  \
# Index
# 0      The e-commerce boom has exacerbated a global t...
# 1      Working in a factory can mean doing the same t...
# 2      In a Hong Kong warehouse, a swarm of autonomou...
# 3      Here's a look at how the pandemic reshaped peo...
# 4      March Madness isn't just for college basketbal...
#
#                                                  content
# Index
# 0       (CNN)Right now, there's a shortage of truck d...
# 1       (CNN)Working in a factory or warehouse can me...
# 2       (CNN)In a Hong Kong warehouse, a swarm of aut...
# 3      The pandemic thrust the working world into a n...
# 4      New York (CNN Business)March Madness isn't jus...

# %%
cnn_data.groupby("category").count()
# Out:
#                source   date  section  title  description  content
# category
# business          854    854      854    854          854      854
# entertainment     413    413      413    413          413      413
# health            557    557      557    557          557      557
# news            18077  18077    18077  18077        18077    18069
# politics         2461   2461     2461   2461         2461     2461
# sport           15542  15542    15542  15542        15542    15541
# style               1      1        1      1            1        1
# travel             39     39       39     39           39       39
# vr                  5      5        5      5            5        5

# %%
cnn_data.groupby(["category", "section"]).count()
# Out:
#                                     source   date  title  description  content
# category      section
# business      business                 284    284    284          284      284
#               business-food              4      4      4            4        4
#               business-india             1      1      1            1        1
#               business-money             3      3      3            3        3
#               cars                       7      7      7            7        7
#               economy                   64     64     64           64       64
#               energy                    21     21     21           21       21
#               homes                     15     15     15           15       15
#               intl_business              1      1      1            1        1
#               investing                 82     82     82           82       82
#               media                     85     85     85           85       85
#               perspectives              41     41     41           41       41
#               success                   41     41     41           41       41
#               tech                     205    205    205          205      205
# entertainment celebrities                1      1      1            1        1
#               entertainment            390    390    390          390      390
#               movies                     1      1      1            1        1
#               showbiz                   21     21     21           21       21
# health        health                   557    557    557          557      557
# news          africa                   183    183    183          183      183
#               americas                 217    217    217          217      217
#               app-news-section          30     30     30           30       30
#               app-politics-section       2      2      2            2        2
#               app-tech-section           1      1      1            1        1
#               asia                     301    301    301          301      301
#               australia                547    547    547          547      547
#               china                    103    103    103          103      103
#               cnn10                      1      1      1            1        1
#               europe                 10635  10635  10635        10635    10627
#               india                     28     28     28           28       28
#               intl_world                 1      1      1            1        1
#               justice                   25     25     25           25       25
#               living                    93     93     93           93       93
#               middleeast               148    148    148          148      148
#               opinion                  188    188    188          188      188
#               opinions                 850    850    850          850      850
#               uk                      1856   1856   1856         1856     1856
#               us                      2119   2119   2119         2119     2119
#               weather                  131    131    131          131      131
#               world                    614    614    614          614      614
#               worldsport                 4      4      4            4        4
# politics      politics                2461   2461   2461         2461     2461
# sport         equestrian                 3      3      3            3        3
#               football                4911   4911   4911         4911     4911
#               golf                    1498   1498   1498         1498     1498
#               horseracing                1      1      1            1        1
#               motorsport              1386   1386   1386         1386     1386
#               sailing                    1      1      1            1        1
#               skiing                     3      3      3            3        3
#               sport                   5639   5639   5639         5639     5638
#               tennis                  2100   2100   2100         2100     2100
# style         fashion                    1      1      1            1        1
# travel        foodanddrink               1      1      1            1        1
#               travel                    38     38     38           38       38
# vr            vr                         5      5      5            5        5

# %% [markdown]
# # Merged Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Merge and write

# %%
df = pd.concat([
    bbcnd_data,
    na_data,
    cnn_data
])[["source", "date", "title", "category", "description", "content"]]

df.source = df.source.str.strip()
df.title = df.title.str.strip()
df.category = df.category.str.strip()
df.description = df.description.str.strip()
df.content = df.content.str.strip()

df.content = df.content.map(lambda s: s if s!="" else None)
df.title = df.title.map(lambda s: s if s!="" else None)
df.description = df.description.map(lambda s: s if s!="" else None)

df.reset_index(drop=True)
df.drop_duplicates(inplace=True)
df.dropna(subset=["title", "content"], inplace=True)

df
# Out:
#          source        date  \
# 0      BBC News         NaN
# 1      BBC News         NaN
# 2      BBC News         NaN
# 3      BBC News         NaN
# 4      BBC News         NaN
# ...         ...         ...
# 44992       CNN  2022-03-01
# 44993       CNN  2022-03-01
# 44994       CNN  2022-03-01
# 44996       CNN  2013-01-12
# 44997       CNN  2013-06-27
#
#                                                    title  category  \
# 0                      Ad sales boost Time Warner profit  business
# 1                       Dollar gains on Greenspan speech  business
# 2                      Yukos unit buyer faces loan claim  business
# 3                      High fuel prices hit BA's profits  business
# 4                      Pernod takeover talk lifts Domecq  business
# ...                                                  ...       ...
# 44992  Russian President Vladimir Putin is being stri...     sport
# 44993  On NATO's doorstep, a former tourist hotspot i...      news
# 44994  MLB is postponing Opening Day after owners and...     sport
# 44996                 Mikhail Gorbachev Fast Facts - CNN      news
# 44997                   Duchess Camilla Fast Facts - CNN      news
#
#                                              description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44992  Russian President Vladimir Putin has been stri...
# 44993  A long line of men snakes out of an unassuming...
# 44994  Major League Baseball (MLB) is postponing its ...
# 44996  Read CNN's Fast Facts on Mikhail Gorbachev, fo...
# 44997  Read CNN's Fast Facts on Duchess Camilla, the ...
#
#                                                  content
# 0      Quarterly profits at US media giant TimeWarner...
# 1      The dollar has hit its highest level against t...
# 2      The owners of embattled Russian oil giant Yuko...
# 3      British Airways has blamed high fuel prices fo...
# 4      Shares in UK drinks and food firm Allied Domec...
# ...                                                  ...
# 44992  (CNN)Russian President Vladimir Putin has been...
# 44993  Lviv, Ukraine (CNN)A long line of men snakes o...
# 44994  (CNN)Major League Baseball (MLB) is postponing...
# 44996  Here's a look at the life of Mikhail Gorbachev...
# 44997  (CNN)Here's a look at the life of Her Royal Hi...
#
# [42635 rows x 6 columns]

# %%
df.to_csv("data/news-data.csv")

# %% [markdown]
# ## Read merged

# %%
df = pd.read_csv("data/news-data.csv", dtype={"content": str})
df.drop(columns=["Unnamed: 0"], inplace=True)
df.date = pd.to_datetime(df.date).dt.date
df.head()
# Out:
#      source date                              title  category description  \
# 0  BBC News  NaT  Ad sales boost Time Warner profit  business         NaN
# 1  BBC News  NaT   Dollar gains on Greenspan speech  business         NaN
# 2  BBC News  NaT  Yukos unit buyer faces loan claim  business         NaN
# 3  BBC News  NaT  High fuel prices hit BA's profits  business         NaN
# 4  BBC News  NaT  Pernod takeover talk lifts Domecq  business         NaN
#
#                                              content
# 0  Quarterly profits at US media giant TimeWarner...
# 1  The dollar has hit its highest level against t...
# 2  The owners of embattled Russian oil giant Yuko...
# 3  British Airways has blamed high fuel prices fo...
# 4  Shares in UK drinks and food firm Allied Domec...

# %% [markdown]
# ## Analysis
#
# Общее число статей -- 42635, из них статей с датами -- 40508. Статьи без дат относятся к датасету `BBC News Data`, в котором представлены статьи за 2004-2005 годы. Статьи, даты которых указаны, датированы 2011-2022 годами: самая старая -- `2011.08.24`, самая новая -- `2022.03.21`.
#
# Основные категории статей:
#  - `business`
#  - `entertainment`
#  - `health`
#  - `politics`
#  - `sport`
#  - `tech`
#  - `travel`
# Новости, помеченные как `news`, как правило, являются общими новостями. В датасете `CNN News Articles` для новостей также указывалась их географическая принадлежность. Более подробная статистика по категориям представлена в таблице ниже.

# %%
# какому источнику принадлежат статьи без дат
df[~df.date.notnull()].groupby("source").count()
# Out:
#           date  title  category  description  content
# source
# BBC News     0   2127      2127            0     2127

# %%
# даты самой старой и самой новой статей
df.date[df.date.notnull()].min(), df.date[df.date.notnull()].max()
# Out:
# (datetime.date(2011, 8, 24), datetime.date(2022, 3, 21))

# %%
df.describe()
# Out:
#        source        date                                title category  \
# count   42635       40508                                42635    42635
# unique      3        3841                                42508       10
# top       CNN  2022-03-16  Must-watch videos of the week - CNN     news
# freq    37923          80                                   14    18067
#
#                                               description content
# count                                               37899   42635
# unique                                              37807   42588
# top     A version of this article first appeared in th...   (CNN)
# freq                                                    6       7

# %%
df.groupby("source").count()
# Out:
#            date  title  category  description  content
# source
# BBC News      0   2127      2127            0     2127
# CNN       37923  37923     37923        37899    37923
# The News   2585   2585      2585            0     2585

# %%
df.groupby("category").count()
# Out:
#                source   date  title  description  content
# category
# business         2534   2031   2534          853     2534
# entertainment     782    413    782          413      782
# health            557    557    557          557      557
# news            18067  18067  18067        18056    18067
# politics         2864   2461   2864         2461     2864
# sport           17439  16934  17439        15514    17439
# style               1      1      1            1        1
# tech              347      0    347            0      347
# travel             39     39     39           39       39
# vr                  5      5      5            5        5

# %%
df.date.notnull().sum() / df.date.notnull().count()
# Out:
# 0.9501114108127126

# %%
plt.hist(
    df.date[df.date.notnull()]
);

# %% [markdown]
# # MongoDB

# %%
import pandas as pd
import numpy as np
import pymongo

# %% [markdown]
# ## Write to DB

# %%
client = pymongo.MongoClient('localhost', 27017)
db = client["news"]
data = db["data"]

# %%
df.date = pd.to_datetime(df.date)
df.date = df.date.astype(object).where(df.date.notnull(), np.nan)
df.reset_index(inplace=True)
df_dict = df.to_dict("records")

# %%
len(df_dict)
# Out:
# 42635

# %%
data.insert_many(df_dict)
